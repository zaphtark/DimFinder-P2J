# %% [markdown]
# ## Load JSON File

# %%
import json

def read_jsonfile(play):
    with open('data/'+play+'.json', 'r', encoding='utf-8') as f:
        play_file = json.load(f)

    return play_file

# %% [markdown]
# ## Get all lines from json

# %%
def get_lines_from_json(play):
    json = read_jsonfile(play)
    all_lines = list()
    for said in json['content']:
        line = {'id':said['id'],'name':said['name'], 'text':[]}
        for verse in said['text']:
            line['text'].append(verse['text'])
        all_lines.append(line)
    return all_lines

# %% [markdown]
# ## Clean (and lemmatize?) text

# %%
from cltk import NLP

nlp = NLP("grc")
# Out:
# ‎𐤀 CLTK version '1.1.6'.
# Pipeline for language 'Ancient Greek' (ISO: 'grc'): `GreekNormalizeProcess`, `GreekStanzaProcess`, `GreekEmbeddingsProcess`, `StopsProcess`.

# %%
from unicodedata import normalize

def clean_texts(list_of_texts, lemma, detailed, diacritics):
    purge_char = [",", ".", ";", ":", "—", "†"]
    if lemma is False: 
        purge_char.append("'")

    clean_texts = list()
    for text in list_of_texts:
        ##Basic preprocessing
        clean_text = text[:]
        clean_text = clean_text.replace("\n", " ")
        for char in purge_char:
            clean_text = clean_text.replace(char, "")
        
        ##Lemmatization
        if lemma is True:
            cltk_doc = nlp.analyze(clean_text)
            clean_text = " ".join([word.lemma for word in cltk_doc.words]) 
        
        #Give every info about word
        if detailed is True:
            cltk_doc = nlp.analyze(clean_text)
            clean_text = [clean_word(word) for word in cltk_doc.words] 
        
        ##Diacritics removal
        if diacritics is False and detailed is False:
            clean_text = normalize("NFKD", clean_text).translate({ord(c): None for c in "̓̔́̀͂̈ͅ"})
            
        clean_texts.append(clean_text)
    return clean_texts

# %%
import copy

def clean_lines(list_of_lines, lemma=False, detailed=False, diacritics=True):
    clean_lines = list()
    for line in list_of_lines:
        clean_text = clean_texts(line['text'], lemma, detailed, diacritics)
        clean_line = copy.deepcopy(line)
        clean_line['text'] = clean_text
        clean_lines.append(clean_line)
    return clean_lines

# %%
def clean_word(word):
    clean_word = dict()
    word_object = vars(word)
    for key in word_object.keys():
        if word_object[key] is not None:
            clean_word[key] = word_object[key]
    return clean_word

# %% [markdown]
# ## Find diminutives with Regex

# %%
import re

# %%
neuter_declension_endings = "(ον|ου|ῳ|α|ων|οις)"

# %%
dim_regex_no_lemma = "(\w*(ι|ί)(ον|ου|ῳ|α|ων|οις)|\w*(ι|ί)σκος)"

# %%
dim_regex_lemma = "(\w*(ι|ί)ον|\w*(ι|ί)σκος)"

# %%
def find_matches(regex, lines):
    matches = list()
    for line in lines:
        for text in line['text']:
            match = re.search(regex, text)
            if match is not None:
                matches.append({'matches':match, 'line_id':line['id']})
    return matches

# %% [markdown]
# ## Find diminutives

# %%
play_results = dict()

# %%
for play in play_names:
    play_results[play] = find_matches(dim_regex_lemma,clean_plays[play])
    text = play + ' \n\n'
    
    for line in play_results[play]:
        matches = line['matches']
        text += matches.group(0) + ' '
        text += str(line['line_id']) + ' '
        text += '\n'
    
    with open('results/'+play+'.txt', 'w', encoding="utf-8") as f:
        f.write(text)

# %%
play_results
# Out:
# {'Acharnians': [{'matches': <re.Match object; span=(30, 36), match='ὄρθιον'>,
#    'line_id': 1},
#   {'matches': <re.Match object; span=(11, 17), match='ἔλαιον'>, 'line_id': 1},
#   {'matches': <re.Match object; span=(21, 31), match='τριπλάσιον'>,
#    'line_id': 31},
#   {'matches': <re.Match object; span=(27, 36), match='Σιβύρτιον'>,
#    'line_id': 47},
#   {'matches': <re.Match object; span=(2, 6), match='Διον'>, 'line_id': 82},
#   {'matches': <re.Match object; span=(22, 26), match='Διον'>, 'line_id': 82},
#   {'matches': <re.Match object; span=(25, 29), match='Διον'>, 'line_id': 93},
#   {'matches': <re.Match object; span=(20, 28), match='τρύβλιον'>,
#    'line_id': 94},
#   {'matches': <re.Match object; span=(28, 41), match='ταραξικάρδιον'>,
#    'line_id': 110},
#   {'matches': <re.Match object; span=(24, 36), match='βουλευτήριον'>,
#    'line_id': 133},
#   {'matches': <re.Match object; span=(22, 30), match='ἐπύλλιον'>,
#    'line_id': 140},
#   {'matches': <re.Match object; span=(11, 17), match='ῥάκιον'>,
#    'line_id': 151},
#   {'matches': <re.Match object; span=(2, 10), match='πιλίδιον'>,
#    'line_id': 164},
#   {'matches': <re.Match object; span=(21, 30), match='βακτήριον'>,
#    'line_id': 166},
#   {'matches': <re.Match object; span=(10, 19), match='σκευάριον'>,
#    'line_id': 168},
#   {'matches': <re.Match object; span=(11, 20), match='σπυρίδιον'>,
#    'line_id': 168},
#   {'matches': <re.Match object; span=(0, 11), match='κοτυλίσκιον'>,
#    'line_id': 174},
#   {'matches': <re.Match object; span=(6, 15), match='σπυρίδιον'>,
#    'line_id': 178},
#   {'matches': <re.Match object; span=(13, 22), match='φιλτάτιον'>,
#    'line_id': 180},
#   {'matches': <re.Match object; span=(15, 23), match='ἀμπέλιον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(5, 14), match='ἀνδράριον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(2, 11), match='χοιρίδιον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(24, 34), match='κἀπιχώριον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(19, 26), match='σκόλιον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(14, 22), match='κυνίδιον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(14, 23), match='παλλάδιον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(23, 30), match='ὑπώπιον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(2, 9), match='νεώριον'>, 'line_id': 184},
#   {'matches': <re.Match object; span=(16, 29), match='πολεμιστήριον'>,
#    'line_id': 190},
#   {'matches': <re.Match object; span=(36, 44), match='Κλείνιον'>,
#    'line_id': 225},
#   {'matches': <re.Match object; span=(20, 27), match='χοίριον'>,
#    'line_id': 229},
#   {'matches': <re.Match object; span=(10, 17), match='χοίριον'>,
#    'line_id': 229},
#   {'matches': <re.Match object; span=(16, 25), match='χοιρίδιον'>,
#    'line_id': 284},
#   {'matches': <re.Match object; span=(2, 11), match='χοιρίδιον'>,
#    'line_id': 290},
#   {'matches': <re.Match object; span=(2, 11), match='χοιρίδιον'>,
#    'line_id': 301},
#   {'matches': <re.Match object; span=(0, 7), match='τἄνθιον'>, 'line_id': 308},
#   {'matches': <re.Match object; span=(0, 10), match='ὀρναπέτιον'>,
#    'line_id': 331},
#   {'matches': <re.Match object; span=(25, 32), match='νεώριον'>,
#    'line_id': 336},
#   {'matches': <re.Match object; span=(0, 7), match='νεώριον'>, 'line_id': 337},
#   {'matches': <re.Match object; span=(23, 30), match='νεώριον'>,
#    'line_id': 340},
#   {'matches': <re.Match object; span=(21, 28), match='ἄγγειον'>,
#    'line_id': 348},
#   {'matches': <re.Match object; span=(7, 16), match='γερόντιον'>,
#    'line_id': 363},
#   {'matches': <re.Match object; span=(19, 28), match='μοσχίδιον'>,
#    'line_id': 363},
#   {'matches': <re.Match object; span=(23, 30), match='γέλοιον'>,
#    'line_id': 403},
#   {'matches': <re.Match object; span=(14, 27), match='προσκεφάλαιον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(22, 28), match='ἴτριον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(6, 14), match='λεκάνιον'>,
#    'line_id': 432},
#   {'matches': <re.Match object; span=(22, 35), match='πολεμιστήριον'>,
#    'line_id': 451},
#   {'matches': <re.Match object; span=(7, 16), match='θοἰμάτιον'>,
#    'line_id': 458},
#   {'matches': <re.Match object; span=(14, 23), match='χειμέριον'>,
#    'line_id': 459},
#   {'matches': <re.Match object; span=(0, 7), match='ὀθόνιον'>, 'line_id': 464},
#   {'matches': <re.Match object; span=(15, 24), match='λαμπάδιον'>,
#    'line_id': 464},
#   {'matches': <re.Match object; span=(24, 32), match='κυδώνιον'>,
#    'line_id': 466},
#   {'matches': <re.Match object; span=(12, 23), match='Λαμαχίππιον'>,
#    'line_id': 468},
#   {'matches': <re.Match object; span=(22, 30), match='Παιώνιον'>,
#    'line_id': 476}],
#  'Birds': [{'matches': <re.Match object; span=(24, 30), match='ἄθλιον'>,
#    'line_id': 4},
#   {'matches': <re.Match object; span=(17, 24), match='στάδιον'>, 'line_id': 4},
#   {'matches': <re.Match object; span=(29, 37), match='τρύβλιον'>,
#    'line_id': 45},
#   {'matches': <re.Match object; span=(18, 25), match='γέλοιον'>,
#    'line_id': 65},
#   {'matches': <re.Match object; span=(0, 9), match='κἀργύριον'>,
#    'line_id': 83},
#   {'matches': <re.Match object; span=(19, 28), match='γυμνάσιον'>,
#    'line_id': 93},
#   {'matches': <re.Match object; span=(2, 12), match='δειλάκριον'>,
#    'line_id': 94},
#   {'matches': <re.Match object; span=(26, 36), match='βαλλάντιον'>,
#    'line_id': 100},
#   {'matches': <re.Match object; span=(25, 35), match='σισύμβριον'>,
#    'line_id': 102},
#   {'matches': <re.Match object; span=(28, 34), match='Μήλιον'>,
#    'line_id': 120},
#   {'matches': <re.Match object; span=(2, 8), match='μήριον'>, 'line_id': 122},
#   {'matches': <re.Match object; span=(25, 35), match='τοὐρνίθιον'>,
#    'line_id': 130},
#   {'matches': <re.Match object; span=(33, 41), match='αἰθέριον'>,
#    'line_id': 196},
#   {'matches': <re.Match object; span=(38, 46), match='τρύβλιον'>,
#    'line_id': 209},
#   {'matches': <re.Match object; span=(5, 13), match='τρύβλιον'>,
#    'line_id': 221},
#   {'matches': <re.Match object; span=(34, 42), match='πινάκιον'>,
#    'line_id': 248},
#   {'matches': <re.Match object; span=(33, 42), match='τεκμήριον'>,
#    'line_id': 263},
#   {'matches': <re.Match object; span=(39, 46), match='ὄρθριον'>,
#    'line_id': 265},
#   {'matches': <re.Match object; span=(39, 44), match='ἔριον'>, 'line_id': 266},
#   {'matches': <re.Match object; span=(21, 30), match='παιδάριον'>,
#    'line_id': 266},
#   {'matches': <re.Match object; span=(42, 51), match='θοἰμάτιον'>,
#    'line_id': 266},
#   {'matches': <re.Match object; span=(19, 25), match='ἔλαιον'>,
#    'line_id': 278},
#   {'matches': <re.Match object; span=(0, 7), match='σίλφιον'>, 'line_id': 278},
#   {'matches': <re.Match object; span=(12, 22), match='κενέβρειον'>,
#    'line_id': 278},
#   {'matches': <re.Match object; span=(16, 25), match='ζευγάριον'>,
#    'line_id': 290},
#   {'matches': <re.Match object; span=(2, 11), match='παιδάριον'>,
#    'line_id': 304},
#   {'matches': <re.Match object; span=(5, 11), match='ῥᾴδιον'>, 'line_id': 315},
#   {'matches': <re.Match object; span=(2, 10), match='αἰθέριον'>,
#    'line_id': 341},
#   {'matches': <re.Match object; span=(16, 25), match='ὑπηνέμιον'>,
#    'line_id': 341},
#   {'matches': <re.Match object; span=(4, 12), match='πηδάλιον'>,
#    'line_id': 342},
#   {'matches': <re.Match object; span=(29, 37), match='ληδάριον'>,
#    'line_id': 342},
#   {'matches': <re.Match object; span=(7, 15), match='αἰθέριον'>,
#    'line_id': 346},
#   {'matches': <re.Match object; span=(17, 26), match='θοἰμάτιον'>,
#    'line_id': 347},
#   {'matches': <re.Match object; span=(17, 24), match='σκάφιον'>,
#    'line_id': 351},
#   {'matches': <re.Match object; span=(0, 9), match='προσόδιον'>,
#    'line_id': 374},
#   {'matches': <re.Match object; span=(0, 7), match='γένειον'>, 'line_id': 386},
#   {'matches': <re.Match object; span=(22, 30), match='ληδάριον'>,
#    'line_id': 393},
#   {'matches': <re.Match object; span=(11, 18), match='κύκλιον'>,
#    'line_id': 394},
#   {'matches': <re.Match object; span=(22, 32), match='Πινδάρειον'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(9, 16), match='ἱμάτιον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(63, 72), match='Ὀλοφύξιον'>,
#    'line_id': 468},
#   {'matches': <re.Match object; span=(30, 39), match='Μουνίχιον'>,
#    'line_id': 472},
#   {'matches': <re.Match object; span=(35, 41), match='Μήλιον'>,
#    'line_id': 481},
#   {'matches': <re.Match object; span=(36, 45), match='Στρούθιον'>,
#    'line_id': 481},
#   {'matches': <re.Match object; span=(11, 20), match='θεσπέσιον'>,
#    'line_id': 482},
#   {'matches': <re.Match object; span=(16, 25), match='παρθένιον'>,
#    'line_id': 482},
#   {'matches': <re.Match object; span=(27, 37), match='βαλλάντιον'>,
#    'line_id': 483},
#   {'matches': <re.Match object; span=(12, 20), match='ἀρχίδιον'>,
#    'line_id': 483},
#   {'matches': <re.Match object; span=(23, 32), match='ναυπήγιον'>,
#    'line_id': 501},
#   {'matches': <re.Match object; span=(20, 29), match='πεδάρσιον'>,
#    'line_id': 513},
#   {'matches': <re.Match object; span=(10, 18), match='αἰθέριον'>,
#    'line_id': 555},
#   {'matches': <re.Match object; span=(0, 9), match='σκυτάλιον'>,
#    'line_id': 555},
#   {'matches': <re.Match object; span=(0, 9), match='Ὀπούντιον'>,
#    'line_id': 555},
#   {'matches': <re.Match object; span=(11, 18), match='σκότιον'>,
#    'line_id': 589},
#   {'matches': <re.Match object; span=(4, 13), match='θοἰμάτιον'>,
#    'line_id': 605},
#   {'matches': <re.Match object; span=(2, 11), match='μειράκιον'>,
#    'line_id': 623},
#   {'matches': <re.Match object; span=(16, 25), match='μειράκιον'>,
#    'line_id': 623},
#   {'matches': <re.Match object; span=(20, 29), match='σκιάδειον'>,
#    'line_id': 654},
#   {'matches': <re.Match object; span=(16, 22), match='μήριον'>,
#    'line_id': 660},
#   {'matches': <re.Match object; span=(13, 22), match='τἀμπόριον'>,
#    'line_id': 660},
#   {'matches': <re.Match object; span=(24, 31), match='νεώριον'>,
#    'line_id': 668},
#   {'matches': <re.Match object; span=(7, 16), match='σκιάδειον'>,
#    'line_id': 674},
#   {'matches': <re.Match object; span=(13, 22), match='θοἰμάτιον'>,
#    'line_id': 677},
#   {'matches': <re.Match object; span=(30, 37), match='σίλφιον'>,
#    'line_id': 683},
#   {'matches': <re.Match object; span=(15, 22), match='σίλφιον'>,
#    'line_id': 685},
#   {'matches': <re.Match object; span=(10, 17), match='σίλφιον'>,
#    'line_id': 688},
#   {'matches': <re.Match object; span=(0, 6), match='ἔλαιον'>, 'line_id': 691},
#   {'matches': <re.Match object; span=(0, 7), match='ὄμβριον'>, 'line_id': 693},
#   {'matches': <re.Match object; span=(15, 25), match='ἀργυρίδιον'>,
#    'line_id': 704},
#   {'matches': <re.Match object; span=(2, 14), match='τρισμακάριον'>,
#    'line_id': 744},
#   {'matches': <re.Match object; span=(10, 18), match='γαμήλιον'>,
#    'line_id': 751}],
#  'Clouds': [{'matches': <re.Match object; span=(22, 35), match='πολεμιστήριον'>,
#    'line_id': 4},
#   {'matches': <re.Match object; span=(20, 25), match='ἔριον'>, 'line_id': 11},
#   {'matches': <re.Match object; span=(16, 25), match='θοἰμάτιον'>,
#    'line_id': 11},
#   {'matches': <re.Match object; span=(0, 6), match='ἔλαιον'>, 'line_id': 12},
#   {'matches': <re.Match object; span=(12, 24), match='Φειδιππίδιον'>,
#    'line_id': 15},
#   {'matches': <re.Match object; span=(24, 32), match='τᾠκίδιον'>,
#    'line_id': 27},
#   {'matches': <re.Match object; span=(22, 35), match='φροντιστήριον'>,
#    'line_id': 29},
#   {'matches': <re.Match object; span=(14, 22), match='ἀργύριον'>,
#    'line_id': 29},
#   {'matches': <re.Match object; span=(19, 32), match='φροντιστήριον'>,
#    'line_id': 41},
#   {'matches': <re.Match object; span=(18, 31), match='φροντιστήριον'>,
#    'line_id': 47},
#   {'matches': <re.Match object; span=(25, 34), match='μυστήριον'>,
#    'line_id': 48},
#   {'matches': <re.Match object; span=(27, 39), match='τοὐρροπύγιον'>,
#    'line_id': 54},
#   {'matches': <re.Match object; span=(15, 24), match='θοἰμάτιον'>,
#    'line_id': 64},
#   {'matches': <re.Match object; span=(24, 37), match='φροντιστήριον'>,
#    'line_id': 65},
#   {'matches': <re.Match object; span=(17, 27), match='πραγμάτιον'>,
#    'line_id': 73},
#   {'matches': <re.Match object; span=(2, 13), match='Σωκρατίδιον'>,
#    'line_id': 99},
#   {'matches': <re.Match object; span=(21, 32), match='Σωκρατίδιον'>,
#    'line_id': 105},
#   {'matches': <re.Match object; span=(18, 27), match='Βυζάντιον'>,
#    'line_id': 111},
#   {'matches': <re.Match object; span=(31, 35), match='χιον'>, 'line_id': 126},
#   {'matches': <re.Match object; span=(19, 26), match='ὄμβριον'>,
#    'line_id': 127},
#   {'matches': <re.Match object; span=(0, 7), match='κύκλιον'>, 'line_id': 145},
#   {'matches': <re.Match object; span=(25, 30), match='ἔριον'>, 'line_id': 150},
#   {'matches': <re.Match object; span=(15, 23), match='ζωμίδιον'>,
#    'line_id': 178},
#   {'matches': <re.Match object; span=(21, 31), match='γαστρίδιον'>,
#    'line_id': 179},
#   {'matches': <re.Match object; span=(31, 38), match='Σούνιον'>,
#    'line_id': 181},
#   {'matches': <re.Match object; span=(19, 28), match='γυμνάσιον'>,
#    'line_id': 185},
#   {'matches': <re.Match object; span=(29, 36), match='στάδιον'>,
#    'line_id': 190},
#   {'matches': <re.Match object; span=(17, 26), match='θοἰμάτιον'>,
#    'line_id': 213},
#   {'matches': <re.Match object; span=(27, 35), match='κωμόδιον'>,
#    'line_id': 227},
#   {'matches': <re.Match object; span=(42, 48), match='ὅρκιον'>,
#    'line_id': 227},
#   {'matches': <re.Match object; span=(6, 14), match='δείλαιον'>,
#    'line_id': 227},
#   {'matches': <re.Match object; span=(31, 38), match='βέλτιον'>,
#    'line_id': 229},
#   {'matches': <re.Match object; span=(6, 13), match='βέλτιον'>,
#    'line_id': 229},
#   {'matches': <re.Match object; span=(0, 6), match='Δήλιον'>, 'line_id': 230},
#   {'matches': <re.Match object; span=(5, 13), match='ἐνόπλιον'>,
#    'line_id': 244},
#   {'matches': <re.Match object; span=(9, 17), match='δείλαιον'>,
#    'line_id': 291},
#   {'matches': <re.Match object; span=(2, 13), match='Σωκρατίδιον'>,
#    'line_id': 315},
#   {'matches': <re.Match object; span=(15, 23), match='τἀγύριον'>,
#    'line_id': 325},
#   {'matches': <re.Match object; span=(21, 30), match='γερόντιον'>,
#    'line_id': 348},
#   {'matches': <re.Match object; span=(4, 13), match='παιδάριον'>,
#    'line_id': 359},
#   {'matches': <re.Match object; span=(17, 26), match='θοἰμάτιον'>,
#    'line_id': 382},
#   {'matches': <re.Match object; span=(19, 26), match='ἠλίθιον'>,
#    'line_id': 391},
#   {'matches': <re.Match object; span=(17, 30), match='ἀναπειστήριον'>,
#    'line_id': 391},
#   {'matches': <re.Match object; span=(12, 21), match='παιδάριον'>,
#    'line_id': 392},
#   {'matches': <re.Match object; span=(15, 24), match='μειράκιον'>,
#    'line_id': 425},
#   {'matches': <re.Match object; span=(3, 11), match='πηρίδιον'>,
#    'line_id': 427},
#   {'matches': <re.Match object; span=(13, 22), match='μειράκιον'>,
#    'line_id': 431},
#   {'matches': <re.Match object; span=(32, 41), match='κεφάλαιον'>,
#    'line_id': 443},
#   {'matches': <re.Match object; span=(21, 28), match='ἱμάτιον'>,
#    'line_id': 445},
#   {'matches': <re.Match object; span=(13, 22), match='μειράκιον'>,
#    'line_id': 445},
#   {'matches': <re.Match object; span=(11, 20), match='μειράκιον'>,
#    'line_id': 446},
#   {'matches': <re.Match object; span=(35, 44), match='γυμνάσιον'>,
#    'line_id': 447},
#   {'matches': <re.Match object; span=(16, 25), match='μειράκιον'>,
#    'line_id': 461},
#   {'matches': <re.Match object; span=(0, 9), match='θοἰμάτιον'>,
#    'line_id': 478},
#   {'matches': <re.Match object; span=(6, 13), match='μέτριον'>,
#    'line_id': 485},
#   {'matches': <re.Match object; span=(21, 34), match='φροντιστήριον'>,
#    'line_id': 485},
#   {'matches': <re.Match object; span=(23, 34), match='τοὐπιχώριον'>,
#    'line_id': 497},
#   {'matches': <re.Match object; span=(19, 29), match='μοὐγκώμιον'>,
#    'line_id': 515},
#   {'matches': <re.Match object; span=(27, 36), match='τἀργύριον'>,
#    'line_id': 541},
#   {'matches': <re.Match object; span=(15, 24), match='τἀργύριον'>,
#    'line_id': 543},
#   {'matches': <re.Match object; span=(16, 25), match='τἀργύριον'>,
#    'line_id': 564},
#   {'matches': <re.Match object; span=(19, 28), match='τἀργύριον'>,
#    'line_id': 567},
#   {'matches': <re.Match object; span=(16, 25), match='τἀργύριον'>,
#    'line_id': 568},
#   {'matches': <re.Match object; span=(12, 21), match='τἀργύριον'>,
#    'line_id': 570},
#   {'matches': <re.Match object; span=(12, 21), match='τἀργύριον'>,
#    'line_id': 573},
#   {'matches': <re.Match object; span=(23, 36), match='φροντιστήριον'>,
#    'line_id': 646},
#   {'matches': <re.Match object; span=(15, 24), match='θοἰμάτιον'>,
#    'line_id': 652}],
#  'Ecclesiazusae': [{'matches': <re.Match object; span=(2, 11), match='θαἰμάτιον'>,
#    'line_id': 1},
#   {'matches': <re.Match object; span=(16, 25), match='θοἰμάτιον'>,
#    'line_id': 4},
#   {'matches': <re.Match object; span=(4, 13), match='θαἰμάτιον'>,
#    'line_id': 20},
#   {'matches': <re.Match object; span=(27, 33), match='δήμιον'>, 'line_id': 23},
#   {'matches': <re.Match object; span=(20, 29), match='Φορμίσιον'>,
#    'line_id': 28},
#   {'matches': <re.Match object; span=(9, 18), match='θαἰμάτιον'>,
#    'line_id': 28},
#   {'matches': <re.Match object; span=(15, 22), match='γένειον'>,
#    'line_id': 34},
#   {'matches': <re.Match object; span=(29, 37), match='Ἀγύρριον'>,
#    'line_id': 66},
#   {'matches': <re.Match object; span=(14, 22), match='ἀργύριον'>,
#    'line_id': 66},
#   {'matches': <re.Match object; span=(11, 19), match='τρύβλιον'>,
#    'line_id': 83},
#   {'matches': <re.Match object; span=(24, 32), match='χιτώνιον'>,
#    'line_id': 92},
#   {'matches': <re.Match object; span=(4, 13), match='θαἰμάτιον'>,
#    'line_id': 92},
#   {'matches': <re.Match object; span=(0, 8), match='ἀργύριον'>, 'line_id': 97},
#   {'matches': <re.Match object; span=(3, 11), match='ἀσκίδιον'>,
#    'line_id': 97},
#   {'matches': <re.Match object; span=(4, 13), match='θοἰμάτιον'>,
#    'line_id': 98},
#   {'matches': <re.Match object; span=(5, 12), match='ἱμάτιον'>,
#    'line_id': 103},
#   {'matches': <re.Match object; span=(16, 25), match='θοἰμάτιον'>,
#    'line_id': 107},
#   {'matches': <re.Match object; span=(14, 23), match='θοἰμάτιον'>,
#    'line_id': 111},
#   {'matches': <re.Match object; span=(19, 27), match='χιτώνιον'>,
#    'line_id': 117},
#   {'matches': <re.Match object; span=(6, 13), match='ὄρθριον'>,
#    'line_id': 121},
#   {'matches': <re.Match object; span=(14, 21), match='ἱμάτιον'>,
#    'line_id': 131},
#   {'matches': <re.Match object; span=(0, 7), match='ἱμάτιον'>, 'line_id': 147},
#   {'matches': <re.Match object; span=(9, 20), match='δικαστήριον'>,
#    'line_id': 156},
#   {'matches': <re.Match object; span=(11, 18), match='βέλτιον'>,
#    'line_id': 168},
#   {'matches': <re.Match object; span=(16, 25), match='θοἰμάτιον'>,
#    'line_id': 174},
#   {'matches': <re.Match object; span=(8, 15), match='ὄρθριον'>,
#    'line_id': 187},
#   {'matches': <re.Match object; span=(11, 20), match='θοἰμάτιον'>,
#    'line_id': 187},
#   {'matches': <re.Match object; span=(17, 24), match='ἱμάτιον'>,
#    'line_id': 193},
#   {'matches': <re.Match object; span=(4, 13), match='θοἰμάτιον'>,
#    'line_id': 196},
#   {'matches': <re.Match object; span=(15, 24), match='τἀργύριον'>,
#    'line_id': 226},
#   {'matches': <re.Match object; span=(34, 42), match='ἀργύριον'>,
#    'line_id': 227},
#   {'matches': <re.Match object; span=(8, 15), match='ἱμάτιον'>,
#    'line_id': 259},
#   {'matches': <re.Match object; span=(2, 13), match='δικαστήριον'>,
#    'line_id': 278},
#   {'matches': <re.Match object; span=(31, 40), match='παιδάριον'>,
#    'line_id': 280},
#   {'matches': <re.Match object; span=(5, 16), match='κληρωτήριον'>,
#    'line_id': 281},
#   {'matches': <re.Match object; span=(4, 13), match='μειράκιον'>,
#    'line_id': 286},
#   {'matches': <re.Match object; span=(20, 29), match='ξυσσίτιον'>,
#    'line_id': 289},
#   {'matches': <re.Match object; span=(31, 41), match='κομμώτριον'>,
#    'line_id': 296},
#   {'matches': <re.Match object; span=(18, 25), match='ὄρθριον'>,
#    'line_id': 296},
#   {'matches': <re.Match object; span=(12, 21), match='σκευάριον'>,
#    'line_id': 297},
#   {'matches': <re.Match object; span=(20, 28), match='τρύβλιον'>,
#    'line_id': 367},
#   {'matches': <re.Match object; span=(0, 9), match='μελύδριον'>,
#    'line_id': 391},
#   {'matches': <re.Match object; span=(0, 11), match='φιλοττάριον'>,
#    'line_id': 393},
#   {'matches': <re.Match object; span=(6, 14), match='παίγνιον'>,
#    'line_id': 398},
#   {'matches': <re.Match object; span=(22, 30), match='ψιμύθιον'>,
#    'line_id': 405},
#   {'matches': <re.Match object; span=(21, 28), match='γρᾴδιον'>,
#    'line_id': 419},
#   {'matches': <re.Match object; span=(13, 20), match='γρᾴδιον'>,
#    'line_id': 449},
#   {'matches': <re.Match object; span=(15, 22), match='γρᾴδιον'>,
#    'line_id': 451},
#   {'matches': <re.Match object; span=(20, 31), match='ἀμφορείδιον'>,
#    'line_id': 522},
#   {'matches': <re.Match object; span=(12, 21), match='μειράκιον'>,
#    'line_id': 531},
#   {'matches': <re.Match object; span=(25, 33), match='τρύβλιον'>,
#    'line_id': 537}],
#  'Frogs': [],
#  'Knights': [{'matches': <re.Match object; span=(11, 20), match='τεκμήριον'>,
#    'line_id': 29},
#   {'matches': <re.Match object; span=(24, 33), match='γερόντιον'>,
#    'line_id': 33},
#   {'matches': <re.Match object; span=(0, 12), match='κοσκυλμάτιον'>,
#    'line_id': 33},
#   {'matches': <re.Match object; span=(12, 23), match='ὀκταπλάσιον'>,
#    'line_id': 33},
#   {'matches': <re.Match object; span=(0, 12), match='βουλευμάτιον'>,
#    'line_id': 43},
#   {'matches': <re.Match object; span=(2, 8), match='λόγιον'>, 'line_id': 55},
#   {'matches': <re.Match object; span=(9, 17), match='ποτήριον'>,
#    'line_id': 61},
#   {'matches': <re.Match object; span=(24, 32), match='ποτήριον'>,
#    'line_id': 62},
#   {'matches': <re.Match object; span=(17, 23), match='αὔριον'>, 'line_id': 89},
#   {'matches': <re.Match object; span=(10, 19), match='τἀμπόριον'>,
#    'line_id': 97},
#   {'matches': <re.Match object; span=(33, 41), match='ποτήριον'>,
#    'line_id': 123},
#   {'matches': <re.Match object; span=(0, 10), match='τριπλάσιον'>,
#    'line_id': 139},
#   {'matches': <re.Match object; span=(14, 25), match='Περγασάσιον'>,
#    'line_id': 156},
#   {'matches': <re.Match object; span=(7, 15), match='δικίδιον'>,
#    'line_id': 172},
#   {'matches': <re.Match object; span=(30, 42), match='βουλευτήριον'>,
#    'line_id': 194},
#   {'matches': <re.Match object; span=(18, 23), match='ὄριον'>, 'line_id': 205},
#   {'matches': <re.Match object; span=(5, 14), match='ἀλιτήριον'>,
#    'line_id': 215},
#   {'matches': <re.Match object; span=(18, 26), match='ἀργύριον'>,
#    'line_id': 229},
#   {'matches': <re.Match object; span=(24, 36), match='βουλευτήριον'>,
#    'line_id': 233},
#   {'matches': <re.Match object; span=(19, 28), match='ξυμπόσιον'>,
#    'line_id': 243},
#   {'matches': <re.Match object; span=(33, 41), match='πηδάλιον'>,
#    'line_id': 243},
#   {'matches': <re.Match object; span=(20, 26), match='ῥόθιον'>,
#    'line_id': 243},
#   {'matches': <re.Match object; span=(0, 9), match='μειράκιον'>,
#    'line_id': 245},
#   {'matches': <re.Match object; span=(24, 32), match='τρύβλιον'>,
#    'line_id': 252},
#   {'matches': <re.Match object; span=(23, 29), match='αὔριον'>,
#    'line_id': 252},
#   {'matches': <re.Match object; span=(25, 35), match='βαλλάντιον'>,
#    'line_id': 262},
#   {'matches': <re.Match object; span=(17, 27), match='τριπλάσιον'>,
#    'line_id': 270},
#   {'matches': <re.Match object; span=(2, 10), match='Δημίδιον'>,
#    'line_id': 277},
#   {'matches': <re.Match object; span=(24, 35), match='ἐργαστήριον'>,
#    'line_id': 287},
#   {'matches': <re.Match object; span=(7, 20), match='περικομμάτιον'>,
#    'line_id': 295},
#   {'matches': <re.Match object; span=(25, 36), match='θωπευμάτιον'>,
#    'line_id': 299},
#   {'matches': <re.Match object; span=(4, 12), match='γυπάριον'>,
#    'line_id': 302},
#   {'matches': <re.Match object; span=(2, 9), match='σίλφιον'>, 'line_id': 330},
#   {'matches': <re.Match object; span=(27, 35), match='τρύβλιον'>,
#    'line_id': 338},
#   {'matches': <re.Match object; span=(7, 16), match='κυλίχνιον'>,
#    'line_id': 339},
#   {'matches': <re.Match object; span=(19, 28), match='ἑλκύδριον'>,
#    'line_id': 339},
#   {'matches': <re.Match object; span=(20, 29), match='δακτύλιον'>,
#    'line_id': 349},
#   {'matches': <re.Match object; span=(15, 24), match='δακτύλιον'>,
#    'line_id': 351},
#   {'matches': <re.Match object; span=(0, 6), match='λόγιον'>, 'line_id': 375},
#   {'matches': <re.Match object; span=(16, 22), match='λόγιον'>,
#    'line_id': 388},
#   {'matches': <re.Match object; span=(16, 22), match='λόγιον'>,
#    'line_id': 391},
#   {'matches': <re.Match object; span=(15, 25), match='τοὐπτάνιον'>,
#    'line_id': 393},
#   {'matches': <re.Match object; span=(23, 29), match='λόγιον'>,
#    'line_id': 399},
#   {'matches': <re.Match object; span=(26, 35), match='βαλάνειον'>,
#    'line_id': 407},
#   {'matches': <re.Match object; span=(0, 9), match='ἀλωπέκιον'>,
#    'line_id': 417},
#   {'matches': <re.Match object; span=(17, 26), match='ἀλωπέκιον'>,
#    'line_id': 418},
#   {'matches': <re.Match object; span=(19, 26), match='πότνιον'>,
#    'line_id': 455},
#   {'matches': <re.Match object; span=(12, 20), match='ἀργύριον'>,
#    'line_id': 473},
#   {'matches': <re.Match object; span=(20, 29), match='τεκμήριον'>,
#    'line_id': 484},
#   {'matches': <re.Match object; span=(2, 11), match='παππίδιον'>,
#    'line_id': 487},
#   {'matches': <re.Match object; span=(27, 36), match='τεκμήριον'>,
#    'line_id': 498},
#   {'matches': <re.Match object; span=(22, 27), match='ὤνιον'>, 'line_id': 505},
#   {'matches': <re.Match object; span=(19, 29), match='νικητήριον'>,
#    'line_id': 507},
#   {'matches': <re.Match object; span=(4, 17), match='Πολυμνήστειον'>,
#    'line_id': 514},
#   {'matches': <re.Match object; span=(33, 41), match='ποτήριον'>,
#    'line_id': 514},
#   {'matches': <re.Match object; span=(31, 40), match='μαρτυριον'>,
#    'line_id': 517},
#   {'matches': <re.Match object; span=(6, 17), match='δικαστήριον'>,
#    'line_id': 517},
#   {'matches': <re.Match object; span=(6, 15), match='σκιάδειον'>,
#    'line_id': 534},
#   {'matches': <re.Match object; span=(2, 11), match='μειράκιον'>,
#    'line_id': 547},
#   {'matches': <re.Match object; span=(22, 30), match='λούτριον'>,
#    'line_id': 556}],
#  'Lysistrata': [{'matches': <re.Match object; span=(14, 25), match='ὀρθοστάδιον'>,
#    'line_id': 22},
#   {'matches': <re.Match object; span=(2, 13), match='κροκωτίδιον'>,
#    'line_id': 23},
#   {'matches': <re.Match object; span=(20, 28), match='χιτώνιον'>,
#    'line_id': 23},
#   {'matches': <re.Match object; span=(14, 24), match='θοὐκάταιον'>,
#    'line_id': 36},
#   {'matches': <re.Match object; span=(30, 36), match='ζώνιον'>, 'line_id': 43},
#   {'matches': <re.Match object; span=(21, 29), match='δωμάτιον'>,
#    'line_id': 90},
#   {'matches': <re.Match object; span=(4, 13), match='τὠργύριον'>,
#    'line_id': 97},
#   {'matches': <re.Match object; span=(2, 9), match='σφάγιον'>, 'line_id': 115},
#   {'matches': <re.Match object; span=(16, 25), match='τριβώνιον'>,
#    'line_id': 156},
#   {'matches': <re.Match object; span=(11, 20), match='κανθήλιον'>,
#    'line_id': 158},
#   {'matches': <re.Match object; span=(2, 13), match='δακτυλίδιον'>,
#    'line_id': 201},
#   {'matches': <re.Match object; span=(10, 19), match='τἀργύριον'>,
#    'line_id': 201},
#   {'matches': <re.Match object; span=(4, 13), match='τἀργύριον'>,
#    'line_id': 223},
#   {'matches': <re.Match object; span=(4, 13), match='τἀργύριον'>,
#    'line_id': 224},
#   {'matches': <re.Match object; span=(22, 30), match='ἀργύριον'>,
#    'line_id': 225},
#   {'matches': <re.Match object; span=(13, 22), match='τἀργύριον'>,
#    'line_id': 228},
#   {'matches': <re.Match object; span=(38, 43), match='ὄριον'>, 'line_id': 267},
#   {'matches': <re.Match object; span=(20, 27), match='γέλοιον'>,
#    'line_id': 274},
#   {'matches': <re.Match object; span=(3, 8), match='ἔριον'>, 'line_id': 280},
#   {'matches': <re.Match object; span=(5, 10), match='ἔριον'>, 'line_id': 281},
#   {'matches': <re.Match object; span=(30, 39), match='βαλάνειον'>,
#    'line_id': 283},
#   {'matches': <re.Match object; span=(29, 39), match='Λείψύδριον'>,
#    'line_id': 302},
#   {'matches': <re.Match object; span=(2, 11), match='δαιμόνιον'>,
#    'line_id': 340},
#   {'matches': <re.Match object; span=(23, 31), match='Μελάνιον'>,
#    'line_id': 347},
#   {'matches': <re.Match object; span=(2, 9), match='πότνιον'>, 'line_id': 361},
#   {'matches': <re.Match object; span=(13, 18), match='Παιον'>, 'line_id': 380},
#   {'matches': <re.Match object; span=(16, 25), match='τεκνίδιον'>,
#    'line_id': 403},
#   {'matches': <re.Match object; span=(29, 36), match='Μύρριον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(14, 23), match='κλινίδιον'>,
#    'line_id': 425},
#   {'matches': <re.Match object; span=(15, 28), match='προσκεφάλαιον'>,
#    'line_id': 435},
#   {'matches': <re.Match object; span=(2, 10), match='στρόφιον'>,
#    'line_id': 441},
#   {'matches': <re.Match object; span=(12, 21), match='κυρσάνιον'>,
#    'line_id': 472},
#   {'matches': <re.Match object; span=(7, 17), match='ἀργυρίδιον'>,
#    'line_id': 502},
#   {'matches': <re.Match object; span=(6, 16), match='βαλλάντιον'>,
#    'line_id': 502},
#   {'matches': <re.Match object; span=(12, 21), match='θαἰμάτιον'>,
#    'line_id': 513},
#   {'matches': <re.Match object; span=(23, 32), match='λισσάνιον'>,
#    'line_id': 541},
#   {'matches': <re.Match object; span=(22, 30), match='πυρίδιον'>,
#    'line_id': 554},
#   {'matches': <re.Match object; span=(14, 23), match='συμπόσιον'>,
#    'line_id': 558},
#   {'matches': <re.Match object; span=(23, 33), match='φυσατήριον'>,
#    'line_id': 561},
#   {'matches': <re.Match object; span=(15, 25), match='Ἀρταμίτιον'>,
#    'line_id': 563},
#   {'matches': <re.Match object; span=(0, 5), match='Ἰήιον'>, 'line_id': 565},
#   {'matches': <re.Match object; span=(14, 20), match='Νύσιον'>,
#    'line_id': 565}],
#  'Peace': [{'matches': <re.Match object; span=(6, 14), match='ἀνάρριον'>,
#    'line_id': 17},
#   {'matches': <re.Match object; span=(14, 23), match='κλιμάκιον'>,
#    'line_id': 19},
#   {'matches': <re.Match object; span=(9, 17), match='ἀργύριον'>,
#    'line_id': 37},
#   {'matches': <re.Match object; span=(13, 21), match='πηδάλιον'>,
#    'line_id': 47},
#   {'matches': <re.Match object; span=(2, 12), match='δειλάκριον'>,
#    'line_id': 66},
#   {'matches': <re.Match object; span=(15, 24), match='σκευάριον'>,
#    'line_id': 74},
#   {'matches': <re.Match object; span=(14, 22), match='σανίδιον'>,
#    'line_id': 74},
#   {'matches': <re.Match object; span=(20, 33), match='πολεμιστήριον'>,
#    'line_id': 89},
#   {'matches': <re.Match object; span=(8, 15), match='πότνιον'>,
#    'line_id': 113},
#   {'matches': <re.Match object; span=(4, 11), match='Λύκειον'>,
#    'line_id': 147},
#   {'matches': <re.Match object; span=(4, 13), match='χοιρίδιον'>,
#    'line_id': 162},
#   {'matches': <re.Match object; span=(14, 23), match='χοιρίδιον'>,
#    'line_id': 170},
#   {'matches': <re.Match object; span=(12, 19), match='βέλτιον'>,
#    'line_id': 191},
#   {'matches': <re.Match object; span=(23, 31), match='κυνίδιον'>,
#    'line_id': 217},
#   {'matches': <re.Match object; span=(2, 9), match='πότνιον'>, 'line_id': 240},
#   {'matches': <re.Match object; span=(23, 27), match='Διον'>, 'line_id': 242},
#   {'matches': <re.Match object; span=(0, 8), match='ἐπύλλιον'>,
#    'line_id': 242},
#   {'matches': <re.Match object; span=(15, 23), match='δοράτιον'>,
#    'line_id': 253},
#   {'matches': <re.Match object; span=(30, 38), match='ταρίχιον'>,
#    'line_id': 255},
#   {'matches': <re.Match object; span=(27, 36), match='μετόρχιον'>,
#    'line_id': 257},
#   {'matches': <re.Match object; span=(19, 28), match='δαιμόνιον'>,
#    'line_id': 259},
#   {'matches': <re.Match object; span=(13, 21), match='ἀμπέλιον'>,
#    'line_id': 259},
#   {'matches': <re.Match object; span=(21, 28), match='πότνιον'>,
#    'line_id': 270},
#   {'matches': <re.Match object; span=(15, 22), match='ἐπίπιον'>,
#    'line_id': 301},
#   {'matches': <re.Match object; span=(11, 22), match='ἀνθρώπισκος'>,
#    'line_id': 314},
#   {'matches': <re.Match object; span=(10, 17), match='Ἴσθμιον'>,
#    'line_id': 356},
#   {'matches': <re.Match object; span=(14, 22), match='ὀπτάνιον'>,
#    'line_id': 361},
#   {'matches': <re.Match object; span=(10, 16), match='αὔριον'>,
#    'line_id': 363},
#   {'matches': <re.Match object; span=(4, 14), match='παγκράτιον'>,
#    'line_id': 363},
#   {'matches': <re.Match object; span=(23, 30), match='ἱέρειον'>,
#    'line_id': 465},
#   {'matches': <re.Match object; span=(16, 25), match='ἐπιδήμιον'>,
#    'line_id': 467},
#   {'matches': <re.Match object; span=(23, 31), match='Ἐλύμνιον'>,
#    'line_id': 489},
#   {'matches': <re.Match object; span=(20, 26), match='αὔριον'>,
#    'line_id': 494},
#   {'matches': <re.Match object; span=(13, 22), match='τἀργύριον'>,
#    'line_id': 519},
#   {'matches': <re.Match object; span=(12, 20), match='σπάρτιον'>,
#    'line_id': 524},
#   {'matches': <re.Match object; span=(15, 24), match='παιδάριον'>,
#    'line_id': 550}],
#  'Plutus': [{'matches': <re.Match object; span=(13, 22), match='μειράκιον'>,
#    'line_id': 45},
#   {'matches': <re.Match object; span=(4, 13), match='τἀργύριον'>,
#    'line_id': 74},
#   {'matches': <re.Match object; span=(13, 22), match='τἀργύριον'>,
#    'line_id': 83},
#   {'matches': <re.Match object; span=(22, 32), match='ἀργυρίδιον'>,
#    'line_id': 86},
#   {'matches': <re.Match object; span=(18, 27), match='τἀργύριον'>,
#    'line_id': 88},
#   {'matches': <re.Match object; span=(9, 17), match='ἀργύριον'>,
#    'line_id': 89},
#   {'matches': <re.Match object; span=(12, 20), match='ἀργύριον'>,
#    'line_id': 92},
#   {'matches': <re.Match object; span=(23, 31), match='κρεᾴδιον'>,
#    'line_id': 148},
#   {'matches': <re.Match object; span=(25, 35), match='ἀργυρίδιον'>,
#    'line_id': 150},
#   {'matches': <re.Match object; span=(12, 20), match='ἀργύριον'>,
#    'line_id': 188},
#   {'matches': <re.Match object; span=(2, 11), match='θαλάττιον'>,
#    'line_id': 228},
#   {'matches': <re.Match object; span=(8, 16), match='ἀργύριον'>,
#    'line_id': 305},
#   {'matches': <re.Match object; span=(5, 13), match='ἀργύριον'>,
#    'line_id': 306},
#   {'matches': <re.Match object; span=(5, 12), match='ἱμάτιον'>,
#    'line_id': 310},
#   {'matches': <re.Match object; span=(45, 54), match='βαλάνειον'>,
#    'line_id': 311},
#   {'matches': <re.Match object; span=(4, 13), match='παιδάριον'>,
#    'line_id': 311},
#   {'matches': <re.Match object; span=(23, 30), match='ἱμάτιον'>,
#    'line_id': 311},
#   {'matches': <re.Match object; span=(43, 56), match='προσκεφάλαιον'>,
#    'line_id': 311},
#   {'matches': <re.Match object; span=(32, 41), match='Διονύσιον'>,
#    'line_id': 314},
#   {'matches': <re.Match object; span=(29, 36), match='βέλτιον'>,
#    'line_id': 333},
#   {'matches': <re.Match object; span=(17, 26), match='βαλάνειον'>,
#    'line_id': 343},
#   {'matches': <re.Match object; span=(25, 32), match='γρήδιον'>,
#    'line_id': 366},
#   {'matches': <re.Match object; span=(2, 9), match='γρᾴδιον'>, 'line_id': 368},
#   {'matches': <re.Match object; span=(22, 29), match='γέλοιον'>,
#    'line_id': 370},
#   {'matches': <re.Match object; span=(26, 34), match='θυείδιον'>,
#    'line_id': 378},
#   {'matches': <re.Match object; span=(26, 34), match='κιβώτιον'>,
#    'line_id': 378},
#   {'matches': <re.Match object; span=(24, 32), match='κιβώτιον'>,
#    'line_id': 380},
#   {'matches': <re.Match object; span=(6, 15), match='τριβώνιον'>,
#    'line_id': 382},
#   {'matches': <re.Match object; span=(28, 36), match='Σφήττιον'>,
#    'line_id': 382},
#   {'matches': <re.Match object; span=(0, 8), match='ἰσχάδιον'>,
#    'line_id': 398},
#   {'matches': <re.Match object; span=(14, 22), match='ἀργύριον'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(2, 11), match='σκευάριον'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(11, 17), match='ἔλαιον'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(16, 24), match='λοπάδιον'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(20, 30), match='πινάκισκος'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(5, 14), match='σκορόδιον'>,
#    'line_id': 400},
#   {'matches': <re.Match object; span=(16, 25), match='παιδάριον'>,
#    'line_id': 401},
#   {'matches': <re.Match object; span=(18, 27), match='σκευάριον'>,
#    'line_id': 413},
#   {'matches': <re.Match object; span=(2, 11), match='τριβώνιον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(18, 27), match='παιδάριον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(5, 13), match='ἐμβάδιον'>,
#    'line_id': 420},
#   {'matches': <re.Match object; span=(11, 20), match='θοἰμάτιον'>,
#    'line_id': 439},
#   {'matches': <re.Match object; span=(25, 34), match='τριβώνιον'>,
#    'line_id': 439},
#   {'matches': <re.Match object; span=(2, 11), match='δακτύλιον'>,
#    'line_id': 440},
#   {'matches': <re.Match object; span=(27, 36), match='τριβώνιον'>,
#    'line_id': 448},
#   {'matches': <re.Match object; span=(29, 36), match='σίλφιον'>,
#    'line_id': 475},
#   {'matches': <re.Match object; span=(15, 24), match='θοἰμάτιον'>,
#    'line_id': 476},
#   {'matches': <re.Match object; span=(13, 23), match='τἀλλότριον'>,
#    'line_id': 483},
#   {'matches': <re.Match object; span=(16, 25), match='τριβώνιον'>,
#    'line_id': 489},
#   {'matches': <re.Match object; span=(18, 25), match='ἱμάτιον'>,
#    'line_id': 491},
#   {'matches': <re.Match object; span=(5, 13), match='ἐμβάδιον'>,
#    'line_id': 492},
#   {'matches': <re.Match object; span=(24, 33), match='μειράκιον'>,
#    'line_id': 507},
#   {'matches': <re.Match object; span=(5, 13), match='ἀργύριον'>,
#    'line_id': 509},
#   {'matches': <re.Match object; span=(4, 11), match='ἱμάτιον'>,
#    'line_id': 509},
#   {'matches': <re.Match object; span=(21, 29), match='χιτώνιον'>,
#    'line_id': 509},
#   {'matches': <re.Match object; span=(22, 31), match='ἱματίδιον'>,
#    'line_id': 509},
#   {'matches': <re.Match object; span=(11, 18), match='ἱμάτιον'>,
#    'line_id': 511},
#   {'matches': <re.Match object; span=(0, 9), match='νηττάριον'>,
#    'line_id': 521},
#   {'matches': <re.Match object; span=(0, 9), match='μυστήριον'>,
#    'line_id': 523},
#   {'matches': <re.Match object; span=(15, 23), match='τἀφόδιον'>,
#    'line_id': 530},
#   {'matches': <re.Match object; span=(10, 19), match='μειράκιον'>,
#    'line_id': 541},
#   {'matches': <re.Match object; span=(23, 31), match='ψιμύθιον'>,
#    'line_id': 563},
#   {'matches': <re.Match object; span=(29, 36), match='γρᾴδιον'>,
#    'line_id': 587},
#   {'matches': <re.Match object; span=(14, 23), match='μειράκιον'>,
#    'line_id': 587},
#   {'matches': <re.Match object; span=(26, 34), match='τρύβλιον'>,
#    'line_id': 593},
#   {'matches': <re.Match object; span=(18, 27), match='σκευάριον'>,
#    'line_id': 613},
#   {'matches': <re.Match object; span=(5, 14), match='ἡγεμόνιον'>,
#    'line_id': 629},
#   {'matches': <re.Match object; span=(24, 31), match='βιότιον'>,
#    'line_id': 632}],
#  'Thesmophoriazusae': [{'matches': <re.Match object; span=(28, 34), match='ῥᾴδιον'>,
#    'line_id': 49},
#   {'matches': <re.Match object; span=(27, 38), match='δικαστήριον'>,
#    'line_id': 57},
#   {'matches': <re.Match object; span=(15, 24), match='δαιμόνιον'>,
#    'line_id': 83},
#   {'matches': <re.Match object; span=(16, 24), match='στρόφιον'>,
#    'line_id': 84},
#   {'matches': <re.Match object; span=(30, 37), match='τίτθιον'>,
#    'line_id': 84},
#   {'matches': <re.Match object; span=(17, 29), match='νυκτερείσιον'>,
#    'line_id': 113},
#   {'matches': <re.Match object; span=(13, 22), match='θοἰμάτιον'>,
#    'line_id': 121},
#   {'matches': <re.Match object; span=(17, 26), match='δελφάκιον'>,
#    'line_id': 146},
#   {'matches': <re.Match object; span=(5, 12), match='ἱμάτιον'>,
#    'line_id': 155},
#   {'matches': <re.Match object; span=(6, 15), match='θυγάτριον'>,
#    'line_id': 184},
#   {'matches': <re.Match object; span=(6, 13), match='πόντιον'>,
#    'line_id': 186},
#   {'matches': <re.Match object; span=(8, 14), match='ἔλαιον'>, 'line_id': 193},
#   {'matches': <re.Match object; span=(22, 29), match='κλίδιον'>,
#    'line_id': 193},
#   {'matches': <re.Match object; span=(6, 15), match='δακτύλιον'>,
#    'line_id': 193},
#   {'matches': <re.Match object; span=(19, 29), match='σφραγίδιον'>,
#    'line_id': 193},
#   {'matches': <re.Match object; span=(0, 9), match='παιδάριον'>,
#    'line_id': 195},
#   {'matches': <re.Match object; span=(26, 33), match='πόσθιον'>,
#    'line_id': 197},
#   {'matches': <re.Match object; span=(15, 24), match='δουλάριον'>,
#    'line_id': 200},
#   {'matches': <re.Match object; span=(26, 35), match='θυγάτριον'>,
#    'line_id': 215},
#   {'matches': <re.Match object; span=(8, 17), match='θοἰμάτιον'>,
#    'line_id': 220},
#   {'matches': <re.Match object; span=(14, 26), match='συσκηνήτριον'>,
#    'line_id': 259},
#   {'matches': <re.Match object; span=(0, 7), match='σκάφιον'>, 'line_id': 267},
#   {'matches': <re.Match object; span=(14, 22), match='στρόφιον'>,
#    'line_id': 272},
#   {'matches': <re.Match object; span=(23, 30), match='ἱμάτιον'>,
#    'line_id': 287},
#   {'matches': <re.Match object; span=(27, 34), match='τιώθιον'>,
#    'line_id': 291},
#   {'matches': <re.Match object; span=(34, 40), match='μήριον'>,
#    'line_id': 292},
#   {'matches': <re.Match object; span=(15, 24), match='σκευάριον'>,
#    'line_id': 306},
#   {'matches': <re.Match object; span=(23, 27), match='Διον'>, 'line_id': 317},
#   {'matches': <re.Match object; span=(16, 23), match='βέλτιον'>,
#    'line_id': 331},
#   {'matches': <re.Match object; span=(2, 11), match='σκιάδειον'>,
#    'line_id': 334},
#   {'matches': <re.Match object; span=(8, 17), match='σκιάδειον'>,
#    'line_id': 334},
#   {'matches': <re.Match object; span=(22, 29), match='σκάφιον'>,
#    'line_id': 335},
#   {'matches': <re.Match object; span=(2, 12), match='Τυνδάρειον'>,
#    'line_id': 381},
#   {'matches': <re.Match object; span=(15, 23), match='ἀργύριον'>,
#    'line_id': 389},
#   {'matches': <re.Match object; span=(11, 19), match='Βάκχειον'>,
#    'line_id': 401},
#   {'matches': <re.Match object; span=(0, 7), match='Βρόμιον'>, 'line_id': 402},
#   {'matches': <re.Match object; span=(0, 8), match='γαμήλιον'>,
#    'line_id': 415},
#   {'matches': <re.Match object; span=(19, 27), match='γαμήλιον'>,
#    'line_id': 481},
#   {'matches': <re.Match object; span=(27, 34), match='ὦλάφιον'>,
#    'line_id': 501},
#   {'matches': <re.Match object; span=(5, 14), match='θοἰμάτιον'>,
#    'line_id': 505},
#   {'matches': <re.Match object; span=(26, 35), match='τυγάτριον'>,
#    'line_id': 506},
#   {'matches': <re.Match object; span=(18, 27), match='θοἰμάτιον'>,
#    'line_id': 509},
#   {'matches': <re.Match object; span=(0, 9), match='τἀργύριον'>,
#    'line_id': 517},
#   {'matches': <re.Match object; span=(27, 34), match='γρίδιον'>,
#    'line_id': 520},
#   {'matches': <re.Match object; span=(20, 29), match='παιδάριον'>,
#    'line_id': 523},
#   {'matches': <re.Match object; span=(27, 36), match='τυγάτριον'>,
#    'line_id': 527},
#   {'matches': <re.Match object; span=(31, 38), match='γρίδιον'>,
#    'line_id': 527},
#   {'matches': <re.Match object; span=(26, 33), match='γρίδιον'>,
#    'line_id': 527}],
#  'Wasps': [{'matches': <re.Match object; span=(25, 33), match='Σαβάζιον'>,
#    'line_id': 8},
#   {'matches': <re.Match object; span=(14, 22), match='ἐνύπνιον'>,
#    'line_id': 14},
#   {'matches': <re.Match object; span=(17, 26), match='τριβώνιον'>,
#    'line_id': 19},
#   {'matches': <re.Match object; span=(18, 31), match='πανδοκεύτριον'>,
#    'line_id': 19},
#   {'matches': <re.Match object; span=(10, 20), match='τοὐνύπνιον'>,
#    'line_id': 22},
#   {'matches': <re.Match object; span=(16, 24), match='λογίδιον'>,
#    'line_id': 32},
#   {'matches': <re.Match object; span=(24, 33), match='τριβώνιον'>,
#    'line_id': 38},
#   {'matches': <re.Match object; span=(7, 13), match='ῥάκιον'>, 'line_id': 38},
#   {'matches': <re.Match object; span=(14, 22), match='πινάκιον'>,
#    'line_id': 60},
#   {'matches': <re.Match object; span=(19, 28), match='κανθήλιον'>,
#    'line_id': 62},
#   {'matches': <re.Match object; span=(19, 25), match='πώλιον'>, 'line_id': 74},
#   {'matches': <re.Match object; span=(0, 11), match='ὑπογάστριον'>,
#    'line_id': 79},
#   {'matches': <re.Match object; span=(21, 30), match='Βυζάντιον'>,
#    'line_id': 94},
#   {'matches': <re.Match object; span=(18, 27), match='μισθάριον'>,
#    'line_id': 108},
#   {'matches': <re.Match object; span=(2, 13), match='δικαστήριον'>,
#    'line_id': 109},
#   {'matches': <re.Match object; span=(15, 23), match='θυλάκιον'>,
#    'line_id': 113},
#   {'matches': <re.Match object; span=(14, 22), match='κάδισκος'>,
#    'line_id': 114},
#   {'matches': <re.Match object; span=(6, 15), match='μελίττιον'>,
#    'line_id': 127},
#   {'matches': <re.Match object; span=(26, 34), match='καλῴδιον'>,
#    'line_id': 132},
#   {'matches': <re.Match object; span=(5, 14), match='θαἰμάτιον'>,
#    'line_id': 146},
#   {'matches': <re.Match object; span=(7, 14), match='γήτειον'>,
#    'line_id': 175},
#   {'matches': <re.Match object; span=(9, 16), match='γήτειον'>,
#    'line_id': 175},
#   {'matches': <re.Match object; span=(0, 8), match='δικίδιον'>,
#    'line_id': 178},
#   {'matches': <re.Match object; span=(0, 9), match='γυμνάσιον'>,
#    'line_id': 189},
#   {'matches': <re.Match object; span=(40, 47), match='γέλοιον'>,
#    'line_id': 198},
#   {'matches': <re.Match object; span=(24, 33), match='παιδάριον'>,
#    'line_id': 198},
#   {'matches': <re.Match object; span=(14, 23), match='τἀργύριον'>,
#    'line_id': 204},
#   {'matches': <re.Match object; span=(28, 36), match='στράτιον'>,
#    'line_id': 204},
#   {'matches': <re.Match object; span=(15, 26), match='δικαστήριον'>,
#    'line_id': 205},
#   {'matches': <re.Match object; span=(13, 22), match='παππίδιον'>,
#    'line_id': 215},
#   {'matches': <re.Match object; span=(35, 48), match='προσκεφάλαιον'>,
#    'line_id': 219},
#   {'matches': <re.Match object; span=(16, 25), match='μειράκιον'>,
#    'line_id': 221},
#   {'matches': <re.Match object; span=(40, 46), match='ἔλαιον'>,
#    'line_id': 223},
#   {'matches': <re.Match object; span=(36, 42), match='ῥᾴδιον'>,
#    'line_id': 223},
#   {'matches': <re.Match object; span=(16, 22), match='ξένιον'>,
#    'line_id': 225},
#   {'matches': <re.Match object; span=(6, 19), match='δικαστηρίδιον'>,
#    'line_id': 253},
#   {'matches': <re.Match object; span=(6, 14), match='Ἑκάταιον'>,
#    'line_id': 253},
#   {'matches': <re.Match object; span=(21, 29), match='κάδισκος'>,
#    'line_id': 289},
#   {'matches': <re.Match object; span=(4, 12), match='κάδισκος'>,
#    'line_id': 291},
#   {'matches': <re.Match object; span=(30, 38), match='θυμίδιον'>,
#    'line_id': 300},
#   {'matches': <re.Match object; span=(23, 31), match='τρύβλιον'>,
#    'line_id': 325},
#   {'matches': <re.Match object; span=(8, 17), match='δαιμόνιον'>,
#    'line_id': 335},
#   {'matches': <re.Match object; span=(16, 25), match='ξυμπόσιον'>,
#    'line_id': 359},
#   {'matches': <re.Match object; span=(17, 24), match='ἱμάτιον'>,
#    'line_id': 363},
#   {'matches': <re.Match object; span=(29, 41), match='τοὐρροπύγιον'>,
#    'line_id': 365},
#   {'matches': <re.Match object; span=(35, 42), match='τεῖχιον'>,
#    'line_id': 367},
#   {'matches': <re.Match object; span=(0, 5), match='ἔριον'>, 'line_id': 383},
#   {'matches': <re.Match object; span=(9, 19), match='παγκράτιον'>,
#    'line_id': 415},
#   {'matches': <re.Match object; span=(15, 25), match='παγκράτιον'>,
#    'line_id': 416},
#   {'matches': <re.Match object; span=(14, 23), match='κρεκάκιον'>,
#    'line_id': 427},
#   {'matches': <re.Match object; span=(12, 20), match='ἐνύπνιον'>,
#    'line_id': 428},
#   {'matches': <re.Match object; span=(15, 22), match='σκόλιον'>,
#    'line_id': 438},
#   {'matches': <re.Match object; span=(14, 22), match='ἀργύριον'>,
#    'line_id': 445},
#   {'matches': <re.Match object; span=(10, 17), match='γέλοιον'>,
#    'line_id': 446},
#   {'matches': <re.Match object; span=(0, 10), match='σκωμμάτιον'>,
#    'line_id': 452},
#   {'matches': <re.Match object; span=(14, 23), match='σκευάριον'>,
#    'line_id': 455},
#   {'matches': <re.Match object; span=(16, 22), match='αὔριον'>,
#    'line_id': 457},
#   {'matches': <re.Match object; span=(15, 31), match='χρυσομηλολόνθιον'>,
#    'line_id': 459},
#   {'matches': <re.Match object; span=(25, 34), match='μυστήριον'>,
#    'line_id': 459},
#   {'matches': <re.Match object; span=(28, 35), match='ὑπώπιον'>,
#    'line_id': 475},
#   {'matches': <re.Match object; span=(23, 31), match='ἀργύριον'>,
#    'line_id': 491},
#   {'matches': <re.Match object; span=(6, 16), match='Φρυνίχειον'>,
#    'line_id': 536}]}

# %% [markdown]
# ## Get lines by character

# %%
def get_lines_by_character(character, play):
    char_lines = list()
    for line in play:
        if line["name"] == character:
            char_lines.append(line)
    return char_lines

# %%
def get_lines_all_characters(play):
    all_char_lines = dict()
    for line in all_lines:
        if line['name'] in all_char_lines.keys():
            all_char_lines[line['name']].append(line)
        else:
            all_char_lines[line['name']] = [line]
    return all_char_lines

# %% [markdown]
# ## Get lines by gender

# %%
women = ['Λυσιστράτη', 'Καλονίκη', 'Μυρρίνη', 'Λαμπιτώ', 'ΑλληΑλλήΑλλη', 'Πᾶσαι', 'Χορὸς Γυναικῶν', 'Γυνὴ Α', 'Γυνὴ Β', 'Γυνὴ Γ', 'Γυνὴ Α.', 'Γυνὴ Β.', 'Γυνὴ Γ.', 'Γυνὴ Ξ.', 'Γυνὴ Δ', 'Γυνή', 'Γυνὴ']
men = ['Χορὸς γερόντων', 'Πρόβουλοσ', 'Γέρων', 'Κινησίασ', 'Κῆρυξ Λακεδαιμονίων', 'Λάκων', 'ΑθηναῖοσΑθηναῖοσ', 'Αθηναῖος Α.Αθηναῖος Α.', 'Αθηναῖος ΒΑθηναῖος Β', 'Αθηναῖος Β.Αθηναῖος Β.', 'Χορὸς Λακεδαιμονίων', 'Χορὸς Αθηναίων']

# %%
def get_lines_by_gender(play):
    all_lines = {'men':[],'women':[]}
    for line in play:
        if line['name'] in play['women']:
            all_lines['women'].append(line)
        
        if line['name'] in play['men']:
            all_lines['men'].append(line)
    return all_lines
